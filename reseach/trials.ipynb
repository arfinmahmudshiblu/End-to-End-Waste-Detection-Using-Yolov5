# %%
import gdown

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Yolov5 Project\\End-to-End-Waste-Detection-Using-Yolov5'

# %%
url = "https://drive.google.com/file/d/1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61'

# %%
# %pwd
# Out:
# 'd:\\Yolov5 Project\\End-to-End-Waste-Detection-Using-Yolov5'
